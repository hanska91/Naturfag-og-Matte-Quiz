# %%
import locale
import tkinter as tk
from tkinter import messagebox, ttk
import random

# Lokalitet (for å unngå feil med ttkbootstrap)
try:
    locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
except locale.Error:
    locale.setlocale(locale.LC_ALL, '')

from ttkbootstrap import Style
locale.setlocale(locale.LC_ALL, '')

# Opprinnelige quiz-data (lagres separat for reset)
original_quiz_data = [
    {
        "question": "Hva er hovedforskjellen mellom tradisjonell og moderne bioteknologi?",
        "options": ["A. Tradisjonell bioteknologi bruker naturlige prosesser, mens moderne bioteknologi bruker genteknologi", "B. Tradisjonell bioteknologi er mer effektiv", "C. Moderne bioteknologi er kun brukt i medisin", "D. Tradisjonell bioteknologi er dyrere"],
        "answer": "A",
        "explanation": "Tradisjonell bioteknologi bruker naturlige prosesser som fermentering, mens moderne bioteknologi inkluderer genteknologi og molekylærbiologi."
    },
    {
        "question": "Hva er kloning?",
        "options": ["A. Å lage genetiske kopier av organismer", "B. Å redigere gener i en organisme", "C. Å lage kunstige organer", "D. Å øke veksthastigheten til planter"],
        "answer": "A",
        "explanation": "Kloning er prosessen med å lage genetiske kopier av organismer."
    },
    {
        "question": "Hva er et etisk dilemma ved bruk av kloning?",
        "options": ["A. Økt matproduksjon", "B. Potensielle helsefarer", "C. Bedre smak", "D. Redusert genetisk mangfold"],
        "answer": "D",
        "explanation": "Et etisk dilemma ved bruk av kloning er redusert genetisk mangfold, som kan påvirke økosystemer og arter."
    },
    {
        "question": "Hva kan stamceller brukes til?",
        "options": ["A. Å bekjempe infeksjoner", "B. Å lage ulike celletyper", "C. Å reparere DNA", "D. Å forhindre aldring"],
        "answer": "B",
        "explanation": "Stamceller kan utvikle seg til ulike celletyper og brukes i forskning på sykdomsbehandling."
    },
    {
        "question": "Hva er et etisk dilemma ved bruk av stamceller?",
        "options": ["A. Økt matproduksjon", "B. Potensielle helsefarer", "C. Bruk av embryonale stamceller", "D. Redusert bruk av sprøytemidler"],
        "answer": "C",
        "explanation": "Et etisk dilemma ved bruk av stamceller er bruken av embryonale stamceller, som reiser spørsmål om livets begynnelse og rettigheter."
    },
    {
        "question": "Hva betyr GMO?",
        "options": ["A. Genmodifiserte organismer", "B. Genetisk mikset organismer", "C. Gener med overføring", "D. Genetisk moderne organismer"],
        "answer": "A",
        "explanation": "GMO står for genmodifiserte organismer, som betyr organismer med endret arvemateriale."
    },
    {
        "question": "Hva er CRISPR-teknologi mest kjent for?",
        "options": ["A. Å klone organismer", "B. Å klippe og lime DNA presist", "C. Å øke veksthastigheten til planter", "D. Å lage kunstige organer"],
        "answer": "B",
        "explanation": "CRISPR brukes til å redigere DNA på en presis og effektiv måte."
    },
    {
        "question": "Hva er et etisk dilemma ved bruk av GMO?",
        "options": ["A. Økt matproduksjon", "B. Potensielle helsefarer", "C. Bedre smak", "D. Redusert bruk av sprøytemidler"],
        "answer": "B",
        "explanation": "Et etisk dilemma ved bruk av GMO er potensielle helsefarer og miljøpåvirkninger."
    },
    {
        "question": "Hva brukes DNA-profiler til?",
        "options": ["A. Å bestemme kjønn", "B. Å identifisere personer", "C. Å forbedre synet", "D. Å lage nye organismer"],
        "answer": "B",
        "explanation": "DNA-profiler brukes for å identifisere personer, for eksempel i rettsmedisin."
    },
    {
        "question": "Hva er genterapi?",
        "options": ["A. Å klone organismer", "B. Å redigere gener for å behandle sykdommer", "C. Å lage kunstige organer", "D. Å øke veksthastigheten til planter"],
        "answer": "B",
        "explanation": "Genterapi innebærer å redigere gener for å behandle eller forebygge sykdommer."
    },
    {
        "question": "Hva er et etisk dilemma ved bruk av genteknologi?",
        "options": ["A. Økt matproduksjon", "B. Muligheten for designerbabyer", "C. Bedre smak", "D. Redusert bruk av sprøytemidler"],
        "answer": "B",
        "explanation": "Muligheten for å skape 'designerbabyer' er et etisk dilemma knyttet til genteknologi."
    },
    {
        "question": "Hva er et annet etisk dilemma ved bruk av genteknologi?",
        "options": ["A. Økt matproduksjon", "B. Potensielle helsefarer", "C. Bedre smak", "D. Redusert bruk av sprøytemidler"],
        "answer": "B",
        "explanation": "Et etisk dilemma ved bruk av genteknologi er potensielle helsefarer og miljøpåvirkninger."
    },
    {
        "question": "Hva er avl?",
        "options": ["A. Å redigere gener i en organisme", "B. Å lage genetiske kopier av organismer", "C. Å selektere og pare organismer for ønskede egenskaper", "D. Å lage kunstige organer"],
        "answer": "C",
        "explanation": "Avl er prosessen med å selektere og pare organismer for å oppnå ønskede egenskaper."
    },
    {
        "question": "Hvilken risiko er knyttet til genterapi?",
        "options": ["A. Allergiske reaksjoner", "B. Utilsiktede genetiske endringer", "C. Økt metabolisme", "D. Forbedret immunforsvar"],
        "answer": "B",
        "explanation": "En risiko ved genterapi er utilsiktede genetiske endringer som kan føre til komplikasjoner."
    },
    {
        "question": "Hva er et etisk dilemma ved bruk av genterapi?",
        "options": ["A. Økt matproduksjon", "B. Potensielle helsefarer", "C. Bedre smak", "D. Uforutsigbare langtidseffekter"],
        "answer": "D",
        "explanation": "Et etisk dilemma ved bruk av genterapi er uforutsigbare langtidseffekter på mennesker og fremtidige generasjoner."
    },
    {
        "question": "Hva er etisk kontroversielt med gentester?",
        "options": ["A. De er unøyaktige", "B. Personvern og diskriminering", "C. De er for dyre", "D. De tar for lang tid"],
        "answer": "B",
        "explanation": "Gentester kan være etisk kontroversielle på grunn av personvern og risiko for diskriminering basert på genetisk informasjon."
    },
    {
        "question": "Hva er DNA-sekvensering?",
        "options": ["A. En metode for å klone DNA", "B. En teknikk for å bestemme rekkefølgen av nukleotider i DNA", "C. En prosess for å lage genetiske kopier av organismer", "D. En metode for å redigere gener"],
        "answer": "B",
        "explanation": "DNA-sekvensering er en teknikk som brukes for å bestemme rekkefølgen av nukleotider i et DNA-molekyl."
    },
    {
        "question": "Hva står PGD for, og hva brukes det til?",
        "options": ["A. Preimplantasjon genetisk diagnostikk, brukt for å identifisere genetiske defekter i embryoer før implantasjon", "B. Postnatal genetisk diagnostikk, brukt for å identifisere genetiske defekter etter fødsel", "C. Prenatal genetisk diagnostikk, brukt for å identifisere genetiske defekter under graviditet", "D. Preimplantasjon genetisk diagnostikk, brukt for å klone embryoer"],
        "answer": "A",
        "explanation": "PGD står for preimplantasjon genetisk diagnostikk og brukes for å identifisere genetiske defekter i embryoer før de implanteres i livmoren."
    },
    {
        "question": "Hva er NIPT?",
        "options": ["A. En metode for å redigere gener", "B. En ikke-invasiv prenatal test for å oppdage kromosomavvik hos fosteret", "C. En teknikk for å klone embryoer", "D. En metode for å lage genetiske kopier av organismer"],
        "answer": "B",
        "explanation": "NIPT står for ikke-invasiv prenatal test og brukes for å oppdage kromosomavvik hos fosteret ved å analysere fosterets DNA i morens blod."
    },
    {
        "question": "Hva er Huntingtons sykdom?",
        "options": ["A. En genetisk sykdom som påvirker muskelstyrken", "B. En arvelig nevrodegenerativ sykdom som påvirker hjernen", "C. En infeksjonssykdom som påvirker lungene", "D. En genetisk sykdom som påvirker synet"],
        "answer": "B",
        "explanation": "Huntingtons sykdom er en arvelig nevrodegenerativ sykdom som fører til progressiv skade på hjerneceller."
    },
    {
        "question": "Hva er Duchennes muskeldystrofi?",
        "options": ["A. En genetisk sykdom som påvirker synet", "B. En arvelig muskelsykdom som fører til progressiv muskelsvakhet", "C. En infeksjonssykdom som påvirker lungene", "D. En genetisk sykdom som påvirker hjernen"],
        "answer": "B",
        "explanation": "Duchennes muskeldystrofi er en arvelig muskelsykdom som fører til progressiv muskelsvakhet og tap av muskelmasse."
    },
    {
        "question": "Hva er Golden Rice?",
        "options": ["A. En type ris som er genetisk modifisert for å inneholde vitamin A", "B. En type ris som vokser raskere enn vanlig ris", "C. En type ris som er resistent mot skadedyr", "D. En type ris som er genetisk modifisert for å inneholde jern"],
        "answer": "A",
        "explanation": "Golden Rice er en type ris som er genetisk modifisert for å inneholde beta-karoten, som kroppen omdanner til vitamin A."
    },
    {
        "question": "Hva er biodrivstoff?",
        "options": ["A. Drivstoff laget av fossile brensler", "B. Drivstoff laget av fornybare biologiske materialer", "C. Drivstoff laget av kjemiske forbindelser", "D. Drivstoff laget av genetisk modifiserte organismer"],
        "answer": "B",
        "explanation": "Biodrivstoff er drivstoff laget av fornybare biologiske materialer som planter og alger."
    },
    {
        "question": "Hvordan har CRISPR-teknologi bidratt til å redusere bruk av sprøytemidler mot soppen meldugg?",
        "options": ["A. Ved å klone planter som er resistente mot meldugg", "B. Ved å redigere gener i planter for å gjøre dem resistente mot meldugg", "C. Ved å lage kunstige sprøytemidler", "D. Ved å øke veksthastigheten til planter"],
        "answer": "B",
        "explanation": "CRISPR-teknologi brukes til å redigere gener i planter for å gjøre dem resistente mot soppen meldugg, noe som reduserer behovet for sprøytemidler."
    },
    {
        "question": "Hva er et etisk dilemma ved bruk av GMO-griser som er motstandsdyktige mot virus som gir svinepest?",
        "options": ["A. Økt matproduksjon", "B. Potensielle helsefarer", "C. Bedre smak", "D. Redusert bruk av sprøytemidler"],
        "answer": "B",
        "explanation": "Et etisk dilemma ved bruk av GMO-griser er potensielle helsefarer og miljøpåvirkninger."
    },
    {
        "question": "Hva er CRISPR-CAS9 proteiner kjent for?",
        "options": ["A. Å klone organismer", "B. Å klippe og lime DNA presist", "C. Å øke veksthastigheten til planter", "D. Å lage kunstige organer"],
        "answer": "B",
        "explanation": "CRISPR-CAS9 proteiner brukes til å redigere DNA på en presis og effektiv måte."
    },
    {
        "question": "Hva gjør enzymer som bryter ned plast?",
        "options": ["A. De redigerer gener i bakterier", "B. De kloner bakterier", "C. De bryter ned plast til mindre molekyler", "D. De lager kunstige organer"],
        "answer": "C",
        "explanation": "Enzymer som bryter ned plast, katalyserer nedbrytningen av plast til mindre molekyler som kan brytes ned videre av bakterier."
    },
    {
        "question": "Hva er genmodifisering av bakterienes plasmider?",
        "options": ["A. Å lage genetiske kopier av bakterier", "B. Å redigere gener i bakterienes plasmider for å gi dem nye egenskaper", "C. Å øke veksthastigheten til bakterier", "D. Å lage kunstige organer"],
        "answer": "B",
        "explanation": "Genmodifisering av bakterienes plasmider innebærer å redigere gener i plasmidene for å gi bakteriene nye egenskaper, som for eksempel produksjon av medisiner."
    },
    {
        "question": "Hvor stor andel av soya som produseres er genmodifisert?",
        "options": ["A. 50 %", "B. 60 %", "C. 70 %", "D. 80 %"],
        "answer": "D",
        "explanation": "Omtrent 80 % av soya som produseres er genmodifisert for å tåle ugressmidler eller for å forbedre avlingene."
    },
    {
        "question": "Hvor dyrkes 90 % av GMO-planter?",
        "options": ["A. USA, Brasil, Argentina, India og Canada", "B. Kina, Russland, Tyskland, Frankrike og Japan", "C. Australia, New Zealand, Sør-Afrika, Egypt og Mexico", "D. Storbritannia, Italia, Spania, Portugal og Nederland"],
        "answer": "A",
        "explanation": "90 % av arealet det dyrkes GMO-planter er i USA, Brasil, Argentina, India og Canada."
    },
    {
        "question": "Hva er bioteknologiloven og genteknologiloven i Norge?",
        "options": ["A. Lover som regulerer bruk av bioteknologi og genteknologi", "B. Lover som forbyr all bruk av bioteknologi", "C. Lover som tillater ubegrenset bruk av genteknologi", "D. Lover som regulerer import av bioteknologiske produkter"],
        "answer": "A",
        "explanation": "Bioteknologiloven og genteknologiloven i Norge er lover som regulerer bruk av bioteknologi og genteknologi for å sikre etisk og sikker bruk."
    },
    {
        "question": "Hva er mais, oljeraps og soya genmodifisert for å tåle?",
        "options": ["A. Soppinfeksjoner", "B. Ugressmiddelet glyfosfat", "C. Tørke", "D. Skadedyr"],
        "answer": "B",
        "explanation": "Mais, oljeraps og soya er genmodifisert for å tåle ugressmiddelet glyfosfat, som ellers ville ødelagt avlingene."
    },
    {
        "question": "Hva er GMO-mikroorganismers rolle i medisinsk industri?",
        "options": ["A. Å produsere insulin", "B. Å lage plastmaterialer", "C. Å bryte ned plastavfall", "D. Å øke plantevekst"],
        "answer": "A",
        "explanation": "GMO-mikroorganismer, som genmodifiserte bakterier, brukes til å produsere medisiner som insulin til behandling av diabetes."
    },
    {
        "question": "Hvilket land har strenge lover som bioteknologiloven og genteknologiloven?",
        "options": ["A. USA", "B. Norge", "C. Kina", "D. India"],
        "answer": "B",
        "explanation": "Norge har strenge lover som bioteknologiloven og genteknologiloven, som regulerer bruken av bioteknologi og genteknologi."
    },
    {
        "question": "Hva er et mulig etisk dilemma med genetisk modifisering av planter for å tåle sprøytemidler?",
        "options": ["A. Økt matproduksjon", "B. Potensielle miljøkonsekvenser", "C. Bedre smak", "D. Økte kostnader for bønder"],
        "answer": "B",
        "explanation": "Et etisk dilemma er de potensielle miljøkonsekvensene, som for eksempel tap av biologisk mangfold eller uforutsette miljøpåvirkninger."
    },
    {
        "question": "Hvordan kan CRISPR-teknologi bidra til bærekraftig matproduksjon?",
        "options": ["A. Ved å gjøre planter mer motstandsdyktige mot sykdommer", "B. Ved å øke avlingene gjennom kunstig befruktning", "C. Ved å bruke færre naturressurser", "D. Ved å gjøre dyr mer produktive"],
        "answer": "A",
        "explanation": "CRISPR-teknologi kan gjøre planter mer motstandsdyktige mot sykdommer og skadedyr, noe som kan redusere behovet for sprøytemidler."
    },
    {
        "question": "Hva er et mulig problem ved bruk av genmodifiserte organismer (GMO) i landbruket?",
        "options": ["A. Økt avkastning på grunn av redusert skadedyrbekjempelse", "B. Risiko for uforutsette effekter på økosystemet", "C. Økt pris på matvarer", "D. Økt biologisk mangfold"],
        "answer": "B",
        "explanation": "Det er bekymring for at GMO kan ha uforutsette effekter på økosystemet, som for eksempel å påvirke andre arter eller redusere biologisk mangfold."
    },
    {
        "question": "Hvordan fungerer CRISPR-Cas9-teknologien i genmodifisering?",
        "options": ["A. Den klipper DNA-strengen på spesifikke steder", "B. Den kopierer genetiske sekvenser", "C. Den kloner organismer", "D. Den reparerer skadet DNA tilfeldig"],
        "answer": "A",
        "explanation": "CRISPR-Cas9-teknologien fungerer ved å klippe DNA-strengen på spesifikke steder, noe som gjør det mulig å endre eller redigere gener."
    },
    {
        "question": "Hva er hovedformålet med Golden Rice?",
        "options": ["A. Å øke vitamin A-nivåene i ris", "B. Å gjøre ris mer motstandsdyktig mot sykdommer", "C. Å øke avlingen av ris", "D. Å redusere bruken av sprøytemidler i risdyrking"],
        "answer": "A",
        "explanation": "Golden Rice er genmodifisert for å inneholde beta-karoten, som kroppen kan omdanne til vitamin A, og dermed bidra til å redusere vitamin A-mangel."
    },
    {
        "question": "Hva er et eksempel på bruk av genmodifiserte bakterier i helseindustrien?",
        "options": ["A. Produksjon av medisiner som feks. insulin", "B. Produksjon av plastmaterialer", "C. Produksjon av drivstoff", "D. Produksjon av mat"], 
        "answer": "A",
        "explanation": "Genmodifiserte bakterier brukes til å produsere medisiner, som for eksempel insulin for behandling av diabetes."
    },
    {
        "question": "Hva regulerer genteknologiloven i Norge?",
        "options": ["A. Bruken av genteknologi i medisin og forskning", "B. Bruken av bioteknologi i landbruket", "C. Bruken av genmodifiserte organismer i matproduksjon", "D. Bruken av genteknologi i behandling av mennesker og dyr"],
        "answer": "A",
        "explanation": "Genteknologiloven regulerer bruken av genteknologi i medisin, forskning og behandling av mennesker og dyr, for å sikre etisk og sikker praksis."
    },
    {
        "question": "Hva er hovedformålet med bioteknologiloven?",
        "options": ["A. Å beskytte mennesker mot uønskede genetiske endringer", "B. Å regulere bruken av bioteknologi i helsevesenet", "C. Å sikre sikker og etisk bruk av bioteknologi", "D. Å tillate ubegrenset bruk av bioteknologi for medisinske formål"],
        "answer": "C",
        "explanation": "Bioteknologiloven har som hovedformål å sikre etisk og sikker bruk av bioteknologi i Norge, og regulere ulike bioteknologiske metoder og produkter."
    },
    {
        "question": "Hvilket av følgende tiltak er regulert av genteknologiloven i Norge?",
        "options": ["A. Kloning av mennesker", "B. Genmodifisering av planter for matproduksjon", "C. Bruk av genmodifiserte bakterier i industrien", "D. Bruk av genteknologi i medisinsk behandling av mennesker"],
        "answer": "D",
        "explanation": "Genteknologiloven regulerer bruken av genteknologi i medisinsk behandling av mennesker, som for eksempel i behandlingen av genetiske sykdommer."
    },
    {
        "question": "Hva er en viktig etisk bekymring som bioteknologiloven i Norge tar hensyn til?",
        "options": ["A. Redusere matproduksjon", "B. Beskytte mennesker mot genetisk diskriminering", "C. Øke landbruksproduksjon med GMO-planter", "D. Øke bruken av genetiske tester for alle"],
        "answer": "B",
        "explanation": "En viktig etisk bekymring bioteknologiloven tar hensyn til, er å beskytte mennesker mot genetisk diskriminering og misbruk av genetisk informasjon."
    },
    {
        "question": "Hvilket av følgende er et formål med bioteknologiloven?",
        "options": ["A. Å tillate fri bruk av genmodifiserte organismer uten regulering", "B. Å regulere og kontrollere bruk av genmodifiserte organismer i matproduksjon og landbruk", "C. Å gjøre genmodifisering av mennesker lovlig", "D. Å forby alle former for genteknologi"],
        "answer": "B",
        "explanation": "Bioteknologiloven regulerer og kontrollerer bruken av genmodifiserte organismer i matproduksjon og landbruk, med tanke på etikk og sikkerhet."
    },
    {
        "question": "Hvem overvåker og håndhever genteknologiloven i Norge?",
        "options": ["A. Folkehelseinstituttet", "B. Mattilsynet", "C. Norges forskningsråd", "D. Bioteknologirådet"],
        "answer": "D",
        "explanation": "Bioteknologirådet er et statlig organ som gir råd om etiske og juridiske spørsmål knyttet til bioteknologi og håndhever genteknologiloven i Norge."
    },
    {
        "question": "Hva skjer dersom en genetisk modifisert organisme ikke er i tråd med bioteknologiloven?",
        "options": ["A. Den får automatisk godkjenning til bruk", "B. Den kan bli forbudt i Norge", "C. Den får et midlertidig unntak for bruk", "D. Den blir brukt i forskning før videre godkjenning"],
        "answer": "B",
        "explanation": "Dersom en genetisk modifisert organisme ikke er i tråd med bioteknologiloven, kan den bli forbudt i Norge for å beskytte helse, miljø og etikk."
    }


]

# Initialiser GUI
root = tk.Tk()
root.title("Quiz App")
root.geometry("600x550")
style = Style(theme="flatly")
style.configure("TLabel", font=("Helvetica", 16))
style.configure("TButton", font=("Helvetica", 14))

# Globale variabler
score = 0
current_question = 0
choice_btns = []
quiz_data = []
user_answers = []

# Widgets
qs_label = ttk.Label(root, anchor="center", wraplength=500, padding=10)
qs_label.pack(pady=10)

choices_frame = ttk.Frame(root)
choices_frame.pack(pady=10, fill=tk.X)

feedback_label = ttk.Label(root, anchor="center", padding=10, wraplength=500, justify="left")
feedback_label.pack(pady=10)

score_label = ttk.Label(root, text="", anchor="center", padding=10)
score_label.pack(pady=10)

nav_frame = ttk.Frame(root)
nav_frame.pack(pady=10)

prev_btn = ttk.Button(nav_frame, text="Tilbake", command=lambda: previous_question(), state="disabled")
prev_btn.pack(side="left", padx=10)

next_btn = ttk.Button(nav_frame, text="Neste", command=lambda: next_question(), state="disabled")
next_btn.pack(side="left", padx=10)

retry_btn = ttk.Button(root, text="Prøv igjen", command=lambda: restart_quiz(), state="disabled")
retry_btn.pack(pady=10)

progress = ttk.Progressbar(root, orient="horizontal", length=400, mode="determinate")
progress.pack(pady=10)

# --- Funksjoner ---

def restart_quiz():
    global score, current_question, choice_btns, quiz_data, user_answers
    score = 0
    current_question = 0
    quiz_data = original_quiz_data.copy()
    random.shuffle(quiz_data)
    user_answers = [None] * len(quiz_data)
    progress.config(maximum=len(quiz_data), value=0)
    retry_btn.config(state="disabled")
    next_btn.config(state="disabled")
    prev_btn.config(state="disabled")
    show_question()

def show_question():
    global choice_btns
    for btn in choice_btns:
        btn.destroy()
    choice_btns = []

    question = quiz_data[current_question]
    qs_label.config(text=question["question"])
    options = question["options"]

    selected_index = user_answers[current_question]

    for i, option in enumerate(options):
        button = ttk.Button(
            choices_frame,
            text=option,
            command=lambda i=i: check_answer(i),
            style="TButton"
        )
        button.pack(pady=5, fill=tk.X)
        choice_btns.append(button)

    feedback_label.config(text="")
    score_label.config(text="Score: {}/{}".format(score, len(quiz_data)))
    prev_btn.config(state="normal" if current_question > 0 else "disabled")
    next_btn.config(state="disabled")
    retry_btn.config(state="disabled")

    if selected_index is not None:
        apply_feedback_colors(selected_index)
        next_btn.config(state="normal")

def check_answer(choice_index):
    global score
    question = quiz_data[current_question]
    selected_letter = chr(65 + choice_index)
    correct_letter = question["answer"]
    correct_index = ord(correct_letter) - 65
    previous = user_answers[current_question]

    # Juster score hvis bytter svar
    if previous is not None and chr(65 + previous) == correct_letter:
        score -= 1

    user_answers[current_question] = choice_index

    if selected_letter == correct_letter:
        score += 1
        feedback_label.config(text="Riktig!\n" + question['explanation'], foreground="green")
    else:
        feedback_label.config(
    text=f"Galt! Det riktige svaret er {correct_letter}.\n{question['explanation']}",
    foreground="red"
        )

    score_label.config(text="Score: {}/{}".format(score, len(quiz_data)))
    progress['value'] = current_question + 1

    apply_feedback_colors(choice_index)
    next_btn.config(state="normal")

def apply_feedback_colors(selected_index):
    question = quiz_data[current_question]
    correct_index = ord(question["answer"]) - 65

    for i, button in enumerate(choice_btns):
        button.config(state="disabled")
        if i == correct_index:
            button.config(style="success.TButton")
        elif i == selected_index:
            button.config(style="danger.TButton")
        else:
            button.config(style="secondary.TButton")

def next_question():
    global current_question
    if current_question < len(quiz_data) - 1:
        current_question += 1
        show_question()
    else:
        messagebox.showinfo(
            "Quiz gjennomført",
            f"Du fikk {score} av {len(quiz_data)} riktige.\nTakk for at du deltok!"
        )
        retry_btn.config(state="normal")
        next_btn.config(state="disabled")
        prev_btn.config(state="disabled")

def previous_question():
    global current_question
    if current_question > 0:
        current_question -= 1
        show_question()

# Start første gang
restart_quiz()
root.mainloop()
